# %%
# !pip install pillow 

from PIL import Image  
import os
import numpy as np
# Out:
# Requirement already satisfied: pillow in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (10.0.0)

# %%
data_dir = "./images/"
files = os.listdir(data_dir)

# %%
images = []
for file in files:
    path = os.path.join(data_dir, file)
    images.append(np.array(Image.open(path)))

# %%
import tensorflow as tf

# %%
resized_images = np.array(np.zeros((len(images), 224,224,3)))
for i in range(len(images)):
    resized_images[i] = tf.image.resize(images[i], [224,224])

# %%
preprocessed_images = tf.keras.applications.mobilenet_v2.preprocess_input(resized_images)

# %%
mobilenet_imagenet_model = tf.keras.applications.MobileNetV2(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 [==============================] - 4s 0us/step

# %%
y_pred = mobilenet_imagenet_model.predict(preprocessed_images)
topK = 1
y_pred_top = tf.keras.applications.mobilenet_v2.decode_predictions(y_pred, top=topK)
# Out:
# 1/1 [==============================] - 1s 722ms/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 1us/step

# %%
# !pip install matplotlib

from matplotlib import pyplot as plt
import numpy as np
# Out:
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/6d/f8/ff4acac6ea3f896146fd2a9f76dafb7c36973f2a329cae1d60a7c7252395/matplotlib-3.7.2-cp38-cp38-win_amd64.whl.metadata
#   Downloading matplotlib-3.7.2-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/b2/e5/6a7a6f2bdfcc0a235adf6f40be4f0ab5d23e65b766af1b2570c26b33d3b3/contourpy-1.1.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading contourpy-1.1.0-cp38-cp38-win_amd64.whl.metadata (5.7 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/ee/d1/405b6d7a84cfd43cad518bf3d243433d637ada0add65e93110f5f480f86a/fonttools-4.42.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading fonttools-4.42.1-cp38-cp38-win_amd64.whl.metadata (154 kB)
#      ---------------------------------------- 0.0/154.1 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/154.1 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------  153.6/154.1 kB 2.3 MB/s eta 0:00:01
#      -------------------------------------- 154.1/154.1 kB 1.8 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/1e/93/9dc4ca136063707f12eb56f4c8c294a940dd23f8512834573b201df83f88/kiwisolver-1.4.5-cp38-cp38-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.5-cp38-cp38-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from matplotlib) (10.0.0)
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.3 kB ? eta -:--:--
#      ---------------------------------------- 98.3/98.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\computer\anaconda3\envs\tf2\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.7.2-cp38-cp38-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.5 MB 7.4 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/7.5 MB 7.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/7.5 MB 6.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/7.5 MB 6.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.5 MB 4.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.9/7.5 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.0/7.5 MB 6.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.2/7.5 MB 6.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.5 MB 6.1 MB/s eta 0:00:01
#    --------------- ------------------------ 2.9/7.5 MB 6.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.2/7.5 MB 6.0 MB/s eta 0:00:01
#    ------------------ --------------------- 3.5/7.5 MB 6.0 MB/s eta 0:00:01
#    -------------------- ------------------- 3.8/7.5 MB 6.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.0/7.5 MB 6.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.0/7.5 MB 6.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.0/7.5 MB 5.4 MB/s eta 0:00:01
#    --------------------- ------------------ 4.1/7.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.6/7.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 4.8/7.5 MB 5.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.0/7.5 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 5.3/7.5 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.5/7.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.7/7.5 MB 5.2 MB/s eta 0:00:01
#    ------------------------------- -------- 5.9/7.5 MB 5.1 MB/s eta 0:00:01
#    --------------------------------- ------ 6.2/7.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.4/7.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.5/7.5 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.7/7.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.0/7.5 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.0/7.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.5 MB 4.8 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.3/7.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------  7.4/7.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 4.4 MB/s eta 0:00:00
# Downloading contourpy-1.1.0-cp38-cp38-win_amd64.whl (470 kB)
#    ---------------------------------------- 0.0/470.4 kB ? eta -:--:--
#    ------- -------------------------------- 92.2/470.4 kB 2.6 MB/s eta 0:00:01
#    ------------- -------------------------- 163.8/470.4 kB 2.0 MB/s eta 0:00:01
#    ------------------------ --------------- 286.7/470.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 409.6/470.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 470.4/470.4 kB 2.3 MB/s eta 0:00:00
# Downloading fonttools-4.42.1-cp38-cp38-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.5 MB 3.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.2/1.5 MB 2.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.3/1.5 MB 2.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.5 MB 2.4 MB/s eta 0:00:01
#    --------------- ------------------------ 0.6/1.5 MB 2.6 MB/s eta 0:00:01
#    ------------------- -------------------- 0.7/1.5 MB 2.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.5 MB 2.5 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.5 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 1.2/1.5 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp38-cp38-win_amd64.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.42.1 kiwisolver-1.4.5 matplotlib-3.7.2 pyparsing-3.0.9

# %%
for i in range(len(images)):
    plt.imshow(images[i])
    plt.show()

    for k in range(topK):
        print(f'{y_pred_top[i][k][1]} ({round(y_pred_top[i][k][2] * 100, 1)}%)')
# Out:
# hen (4.3%)
# lycaenid (78.5%)
# leatherback_turtle (31.8%)
# worm_fence (23.2%)
# pelican (99.0%)
